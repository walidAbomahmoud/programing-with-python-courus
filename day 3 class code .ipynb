# %%
tuple = ("MATH" , "ELECTRICITY" , "IT")
print(type(tuple))
print(tuple)
# Out:
# <class 'tuple'>
# ('MATH', 'ELECTRICITY', 'IT')

# %%
set={"arabic" , "english" , "arabic"}
print(set)
# Out:
# {'english', 'arabic'}

# %%
dice = {'name':'john' , 'school':'we school' , 'grade':'2'}
print(dice)
# Out:
# {'name': 'john', 'school': 'we school', 'grade': '2'}

# %%
print(dice.items())
# Out:
# dict_items([('name', 'john'), ('school', 'we school'), ('grade', '2')])

# %%
print(dice.keys())
# Out:
# dict_keys(['name', 'school', 'grade'])

# %%
print(dice.values())
# Out:
# dict_values(['john', 'we school', '2'])

# %%
print(dice["name"])
# Out:
# john

# %%
print(dice["school"])
# Out:
# we school

# %%
data={"name":["john" , "mark" , "sally"] , "school":"we school" , "grade":"2" }
print(data["name"])
# Out:
# ['john', 'mark', 'sally']

# %%
print(data.items())
# Out:
# dict_items([('name', ['john', 'mark', 'sally']), ('school', 'we school'), ('grade', '2')])

# %%
print(data.keys())
# Out:
# dict_keys(['name', 'school', 'grade'])

# %%
print(data.values())
# Out:
# dict_values([['john', 'mark', 'sally'], 'we school', '2'])

# %%
x=10
y=35
if (x>y):
    print("x is grater than y")
elif(x==y):
    print("x is eqal y")
else:
    print("x is less than y")
# Out:
# x is less than y

# %%
a=float (input("enter number"))
if (a>0):
    print("positive")
elif (a==0):
    print("zero")
else:    
    print("negative")
# Out:
# enter number -2
# negative

# %%
i=1
while(i<6):
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5
